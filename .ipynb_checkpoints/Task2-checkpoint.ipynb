# %% [markdown]
# # The Sparsk Foundation

# %% [markdown]
# # Data Science and Business Analytics (GRIP June-21)

# %% [markdown]
# # Task 2- Prediction using Unsupervised ML

# %% [markdown]
# # Author- Kumar Akhil

# %% [markdown]
# # Necessary Imports

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')


sns.set()

plt.style.use("fivethirtyeight")
# %matplotlib inline

# %% [markdown]
# # Loading Data

# %%
iris_df = pd.read_csv('Iris.csv')

iris_df.head() # See the first 5 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Understanding the data

# %%
#information about the data
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#description about the data
iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_df.shape
# Out:
# (150, 6)

# %% [markdown]
# We will drop the column id since it is of no importance

# %%
iris_df.drop('Id',axis=1,inplace=True)

# %%
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Checking for null values
iris_df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# So there is no null values.

# %%
#Count of values of Species
iris_df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
#  Ploting the count of different species.

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Species',data=iris_df.sort_values('SepalLengthCm',ascending=False))
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %% [markdown]
# Relationship between Sepal length and species

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Species',y='SepalLengthCm',data=iris_df.sort_values('SepalLengthCm',ascending=False))
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# Relationship between Sepal width and species

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Species',y='SepalWidthCm',data=iris_df.sort_values('SepalLengthCm',ascending=False))
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %% [markdown]
# Relationship between Petal width and species

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Species',y='PetalWidthCm',data=iris_df.sort_values('SepalLengthCm',ascending=False))
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# Relationship between Sepal length and species

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Species',y='PetalLengthCm',data=iris_df.sort_values('SepalLengthCm',ascending=False))
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# plot between sepla witdht, length and Species

# %%
#Scatter plot
iris_df.plot(kind='scatter',x='SepalWidthCm',y='SepalLengthCm')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %%
#Joint plot
sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_df, size=5)

# %% [markdown]
#  plot between Petal witdht, length and Species

# %%
#Scatter
iris_df.plot(kind='scatter',x='PetalWidthCm',y='PetalLengthCm')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='PetalLengthCm'>

# %%
#Joint plot
sns.jointplot(x="PetalLengthCm", y="PetalWidthCm", data=iris_df, size=5)

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(iris_df, hue="Species", size=3)

# %% [markdown]
# Andrew Curves

# %%
import pandas.plotting
from pandas.plotting import andrews_curves
andrews_curves(iris_df, "Species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# So, from the plots other than S.no evertyhing else have a contribution in deciding the species of the Flower.

# %% [markdown]
# # Determining the value of k

# %%
#Value of X and y
x = iris_df.iloc[:, [ 0,1, 2, 3]].values

# %%
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    

plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# From the above "Elbow Graph" we can see that the elbow forms at 3. So we choose the number of clusters as 3.

# %% [markdown]
# # Creating the K-means classifier

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 200, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# # Predictions

# %%
# Visualising the clusters - On the first two columns
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# # Thank you
